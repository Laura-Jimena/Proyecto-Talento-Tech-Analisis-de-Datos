# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-Jimena/Prueba/blob/main/Co_proyecto_copia1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importación.

# %%
#link https://microdatos.dane.gov.co/index.php/catalog/TECINNO-Microdatos#_r=&collection=&country=&dtype=&from=1970&page=3&ps=&sid=&sk=sort_by=title&sort_order=&to=2024&topic=&view=s&vk=

# %%
import pandas as pd
import plotly.graph_objs as go

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **CON AI**

# %% [markdown]
# Los registros correspondientes al 2020 tienen un número muy bajo de empresas encuestadas (973). De esa manera es mejor establecer una relacion entre 2016-2017 y 2018-2019.

# %%
df2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv', sep=';')
df2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv', sep=';')
df2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv', sep=';')
df_2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv', sep=';')
df_2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv', sep=';')
df_2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv', sep=';')
archivo_csv_vi = "/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv"
archivo_csv_vii = "/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv"
archivo_csv_viii = "/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv"
df_vi = pd.read_csv(archivo_csv_vi, sep=";")
df_vii = pd.read_csv(archivo_csv_vii, sep=";")
df_viii = pd.read_csv(archivo_csv_viii, sep=";")
df_vi['Periodo'] = '2016-2017'
df_vii['Periodo'] = '2018-2019'
df_viii['Periodo'] = '2020-2021'
# Unir los dos datasets
df = pd.concat([df_vi, df_vii, df_viii], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-de3247d1d0ed> in <cell line: 0>()
# ----> 1 df2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv', sep=';')
#       2 df2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv', sep=';')
#       3 df2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv', sep=';')
#       4 df_2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv', sep=';')
#       5 df_2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv', sep=';')
#
# ...

# %%
df_2016 = pd.read_csv('/content/drive/MyDrive/Talento tech/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv', sep=';')
df_2018 = pd.read_csv('/content/drive/MyDrive/Talento tech/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv', sep=';')
df_2020 = pd.read_csv('/content/drive/MyDrive/Talento tech/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv', sep=';')
archivo_csv_vi = "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv"
archivo_csv_vii = "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv"
archivo_csv_viii = "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv"
df_vi = pd.read_csv(archivo_csv_vi, sep=";")
df_vii = pd.read_csv(archivo_csv_vii, sep=";")
df_viii = pd.read_csv(archivo_csv_viii, sep=";")
df_vi['Periodo'] = '2016-2017'
df_vii['Periodo'] = '2018-2019'
df_viii['Periodo'] = '2020-2021'
# Unir los dos datasets
df = pd.concat([df_vi, df_vii, df_viii], ignore_index=True)
# Out:
# <ipython-input-5-cc2af070c947>:3: DtypeWarning: Columns (9,14,16,56,57,70,104,105,108,114,115,116,118,119,122,123,124,125,126,127,130,131,132,133,134,138,139,140,141,144,146,147,148,149,150,152,153,158,160,161,162,163,397,400,403,405,406,408,409,412,414,415,418,421,436,439,476,478,480,481,485,494,502,507,511,512,515,517,519,520,521,522,523,524,525,533,535,537,541,543,545,546,547,548,550,551,554,555,558,559,560,561,562,563,564,566,567,568,569,570,571,572,573,574,575,576,577,580,581,582,586,587,589,592,593,594,596,597,598,599,600,601,602,603,606,607,608,609,611,612,613,614,615,616,621,623,624,626,627,628,629,635,643,646,650,652,654,658,663) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.read_csv('/content/drive/MyDrive/Talento tech/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv', sep=';')
# ...

# %%
df_2020.head()
# Out:
#    NORDEMP_EDITSVIII  NORDEM_EDITSVII  CIIU4  TIPOLO  I1R1C1N  I1R1C2N  \
# 0             987639         987639.0     47  NOINNO        2      NaN
# 1             987636         987636.0     47  NOINNO        2      NaN
# 2             987634         987634.0     47  NOINNO        2      NaN
# 3             987633         987633.0     47  NOINNO        2      NaN
# 4             987622         987622.0     47  NOINNO        2      NaN
#
#    I1R2C1N  I1R2C2N  I1R3C1N I1R3C2N  ...  VIII14R1C1  VIII14R2C1  VIII14R3C1  \
# 0        2      NaN        2     NaN  ...         NaN         NaN         NaN
# 1        2      NaN        2     NaN  ...         NaN         NaN         NaN
# 2        2      NaN        2     NaN  ...         NaN         NaN         NaN
# 3        2      NaN        2     NaN  ...         NaN         NaN         NaN
# 4        2      NaN        2     NaN  ...         NaN         NaN         NaN
#
# ...

# %%
df_2020.describe()
# Out:
#        NORDEMP_EDITSVIII  NORDEM_EDITSVII        CIIU4      I1R1C1N  \
# count       8.812000e+03     8.528000e+03  8812.000000  8812.000000
# mean        1.458344e+07     1.512905e+07   188.155697     1.932138
# std         2.539822e+07     2.604788e+07   232.195035     0.251523
# min         1.000100e+04     1.000100e+04    35.000000     1.000000
# 25%         1.862575e+04     1.861875e+04    46.000000     2.000000
# 50%         7.487415e+05     7.492665e+05    47.000000     2.000000
# 75%         3.402087e+07     3.501251e+07   492.000000     2.000000
# max         8.502120e+07     8.502120e+07   854.000000     2.000000
#
#            I1R1C2N      I1R2C1N    I1R2C2N      I1R3C1N      I1R4C2N  \
# count   598.000000  8812.000000  38.000000  8812.000000   608.000000
# mean      8.530100     1.995688   2.500000     1.999660     8.578947
# std     124.392197     0.065530   4.189756     0.018449   123.373972
# min       1.000000     1.000000   1.000000     1.000000     1.000000
# ...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8812 entries, 0 to 8811
# Columns: 730 entries, NORDEMP_EDITSVIII to VIII19R1C1
# dtypes: float64(480), int64(73), object(177)
# memory usage: 49.1+ MB

# %%
df_2018.head()
# Out:
#    NORDEMP  CIIU4  TIPOLO  I1R1C1N  I1R1C2N  I1R2C1N  I1R2C2N  I1R3C1N  \
# 0   987639     47  NOINNO        2      NaN        2      NaN        2
# 1   987636     47  NOINNO        2      NaN        2      NaN        2
# 2   987634     47  NOINNO        2      NaN        2      NaN        2
# 3   987633     47  NOINNO        2      NaN        2      NaN        2
# 4   987622     47  NOINNO        2      NaN        2      NaN        2
#
#    I1R3C2N  I1R4C2N  ...  VIII14R1C1  VIII14R2C1  VIII14R3C1  VIII14R4C1  \
# 0      NaN      NaN  ...         NaN         NaN         NaN         NaN
# 1      NaN      NaN  ...         NaN         NaN         NaN         NaN
# 2      NaN      NaN  ...         NaN         NaN         NaN         NaN
# 3      NaN      NaN  ...         NaN         NaN         NaN         NaN
# 4      NaN      NaN  ...         NaN         NaN         NaN         NaN
#
#    VIII14R5C1  VIII15R1C1  VIII16R1C1  VIII17R1C1  VIII18R1C1  VIII19R1C1
# ...

# %%
df_2018.describe()
# Out:
#             NORDEMP        CIIU4      I1R1C1N     I1R1C2N      I1R2C1N  \
# count  9.304000e+03  9304.000000  9304.000000  693.000000  9304.000000
# mean   1.514687e+07   186.911758     1.925516    3.679654     1.994089
# std    2.607203e+07   230.646337     0.262571   11.073773     0.076662
# min    1.000100e+04    35.000000     1.000000    1.000000     1.000000
# 25%    1.854800e+04    46.000000     2.000000    1.000000     2.000000
# 50%    7.492495e+05    47.000000     2.000000    2.000000     2.000000
# 75%    3.501797e+07   492.000000     2.000000    3.000000     2.000000
# max    8.502120e+07   854.000000     2.000000  255.000000     2.000000
#
#          I1R2C2N      I1R3C1N     I1R3C2N     I1R4C2N      I1R1C1M  ...  \
# count  55.000000  9304.000000    5.000000  710.000000  9304.000000  ...
# mean    2.309091     1.999463   91.400000    4.414085     1.943250  ...
# std     3.891457     0.023177  191.583663   19.879406     0.231376  ...
# ...

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9304 entries, 0 to 9303
# Columns: 729 entries, NORDEMP to VIII19R1C1
# dtypes: float64(651), int64(77), object(1)
# memory usage: 51.7+ MB

# %%
df_2016.head()
# Out:
#    NORDEMP  CIIU4  TIPOLO  I1R1C1N I1R1C2N  I1R2C1N I1R2C2N  I1R3C1N I1R3C2N  \
# 0   987639     47  AMPLIA        2                2                2
# 1   987636     47  NOINNO        2                2                2
# 2   987634     47  NOINNO        2                2                2
# 3   987633     47  NOINNO        2                2                2
# 4   987622     47  NOINNO        2                2                2
#
#   I1R4C2N  ...  VI7R1C1 VI7R1C2  VI8R1C1 VI9R1C1  VI9R2C1 VI9R3C1 VI9R4C1  \
# 0          ...        2                1
# 1          ...        2                2
# 2          ...        2                2
# 3          ...        2                2
# 4          ...        2                1
#
#    VI9R5C1 VI9R6C1  VI9R7C1
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 638 columns]

# %%
df_2016.describe()
# Out:
#             NORDEMP        CIIU4      I1R1C1N      I1R2C1N      I1R3C1N  \
# count  8.651000e+03  8651.000000  8651.000000  8651.000000  8651.000000
# mean   1.385404e+07   178.771009     1.948330     1.994336     1.998497
# std    2.452451e+07   226.065485     0.221373     0.075051     0.038738
# min    1.000100e+04    35.000000     1.000000     1.000000     1.000000
# 25%    1.769450e+04    46.000000     2.000000     2.000000     2.000000
# 50%    7.495110e+05    47.000000     2.000000     2.000000     2.000000
# 75%    3.401239e+07    86.000000     2.000000     2.000000     2.000000
# max    8.502094e+07   854.000000     2.000000     2.000000     2.000000
#
#           I1R1C1M      I1R2C1M      I1R3C1M       I1R4C1       I1R5C1  ...  \
# count  8651.00000  8651.000000  8651.000000  8651.000000  8651.000000  ...
# mean      1.96197     1.996763     1.999653     1.904173     1.930528  ...
# std       0.19128     0.056802     0.018620     0.294371     0.254269  ...
# ...

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8651 entries, 0 to 8650
# Columns: 638 entries, NORDEMP to VI9R7C1
# dtypes: int64(64), object(574)
# memory usage: 42.1+ MB

# %% [markdown]
# # Periodos

# %%
archivo_csv_vi = "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv"
archivo_csv_vii = "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv"
archivo_csv_viii = "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv"
df_vi = pd.read_csv(archivo_csv_vi, sep=";")
df_vii = pd.read_csv(archivo_csv_vii, sep=";")
df_viii = pd.read_csv(archivo_csv_viii, sep=";")
df_vi['Periodo'] = '2016-2017'
df_vii['Periodo'] = '2018-2019'
df_viii['Periodo'] = '2020-2021'
# Unir los dos datasets
df = pd.concat([df_vi, df_vii, df_viii], ignore_index=True)
# Out:
# <ipython-input-5-8e649eec5880>:6: DtypeWarning: Columns (9,14,16,56,57,70,104,105,108,114,115,116,118,119,122,123,124,125,126,127,130,131,132,133,134,138,139,140,141,144,146,147,148,149,150,152,153,158,160,161,162,163,397,400,403,405,406,408,409,412,414,415,418,421,436,439,476,478,480,481,485,494,502,507,511,512,515,517,519,520,521,522,523,524,525,533,535,537,541,543,545,546,547,548,550,551,554,555,558,559,560,561,562,563,564,566,567,568,569,570,571,572,573,574,575,576,577,580,581,582,586,587,589,592,593,594,596,597,598,599,600,601,602,603,606,607,608,609,611,612,613,614,615,616,621,623,624,626,627,628,629,635,643,646,650,652,654,658,663) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_viii = pd.read_csv(archivo_csv_viii, sep=";")

# %%
df.columns

# %% [markdown]
# # Segunda Tanda

# %% [markdown]
# # **FUNCIÓN PARA LA CREACIÓN DE ESTADISTICOS POR PERIODO Y COLUMNA.**

# %%
 def estadisticos(columna):
  # Asegurar que los datos sean numéricos
  df[columna] = pd.to_numeric(df[columna], errors='coerce')

  # Filtrar datos por período
  s2016 = df[df['Periodo'] == "2016-2017"][columna]
  s2018 = df[df['Periodo'] == "2018-2019"][columna]
  s2020 = df[df['Periodo'] == "2020-2021"][columna]

  # Definir función para calcular estadísticas
  def calcular_estadisticas(data):
      return pd.Series({
          "Cantidad": data.count(),
          "Media": data.mean(),
          "Mediana": data.median(),
          "Moda": data.mode().iloc[0] if not data.mode().empty else np.nan,
          "Varianza": data.var(),
          "Desviación Estándar": data.std(),
          "Asimetría (Cola)": data.skew(),
          "Curtosis": data.kurt(),
          "Mínimo": data.min(),
          "Máximo": data.max(),
          "Percentil 10": data.quantile(0.10),
          "Percentil 90": data.quantile(0.90)
      }).round(2)

  # Calcular estadísticas por período
  stats_2016 = calcular_estadisticas(s2016)
  stats_2018 = calcular_estadisticas(s2018)
  stats_2020 = calcular_estadisticas(s2020)

  # Combinar estadísticas en un solo DataFrame
  final_stats = pd.DataFrame({
      "2016-2017": stats_2016,
      "2018-2019": stats_2018,
      "2020-2021": stats_2020
  })

  # Mostrar la tabla final
  return final_stats

# %% [markdown]
# # Pregunta 1: Evolución del porcentaje de empresas que introdujeron bienes o servicios nuevos

# %%
df_grouped = df.groupby('Periodo')['I1R1C1N'].value_counts(normalize=True).unstack() * 100
df_grouped = df_grouped.rename(columns={1: 'Sí', 2: 'No'})
fig, ax = plt.subplots(figsize=(8, 6))
df_grouped.plot(kind='bar', stacked=True, colormap='coolwarm', ax=ax)
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', label_type='center', fontsize=10, color='white')
plt.title('Porcentaje de empresas con bienes o servicios nuevos por año')
plt.xlabel('Periodo')
plt.ylabel('Porcentaje')
plt.legend(title="Introdujo Innovación")
plt.show()

# %%
estadisticos('I1R1C1N')
# Out:
#                      2016-2017  2018-2019  2020-2021
# Cantidad               8651.00    9304.00    8812.00
# Media                     1.95       1.93       1.93
# Mediana                   2.00       2.00       2.00
# Moda                      2.00       2.00       2.00
# Varianza                  0.05       0.07       0.06
# Desviación Estándar       0.22       0.26       0.25
# Asimetría (Cola)         -4.05      -3.24      -3.44
# Curtosis                 14.42       8.51       9.81
# Mínimo                    1.00       1.00       1.00
# Máximo                    2.00       2.00       2.00
# Percentil 10              2.00       2.00       2.00
# Percentil 90              2.00       2.00       2.00

# %% [markdown]
# # Pregunta 2: Comparación del número promedio de bienes/servicios nuevos por periodo

# %%
#COLORES DE COLORWARM
# #3b4cc0 (azul oscuro)
# #4575b4 (azul medio)
# #91bfdb (azul claro)
# #ffffbf (amarillo claro)
# #fee08b (amarillo suave)
# #fdae61 (naranja suave)
# #d73027 (rojo suave)
# #a50026 (rojo oscuro)

# %%
df['I1R1C2N'] = pd.to_numeric(df['I1R1C2N'], errors='coerce')
df = df.dropna(subset=['I1R1C2N'])
fig, ax = plt.subplots(figsize=(8, 6))
promedios_nuevos = df.groupby('Periodo')['I1R1C2N'].mean()
promedios_nuevos.plot(kind='bar', color=["#a50026", "#3b4cc0",'#d73027'], ax=ax)
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=12, color='black')
plt.title('Promedio de bienes/servicios nuevos por empresa')
plt.xlabel('Periodo')
plt.ylabel('Promedio')
plt.show()

# %%
estadisticos('I1R1C2N')
# Out:
#                      2016-2017  2018-2019  2020-2021
# Cantidad                447.00     693.00     598.00
# Media                     7.43       3.68       8.53
# Mediana                   1.00       2.00       1.00
# Moda                      1.00       1.00       1.00
# Varianza               1670.59     122.63   15473.42
# Desviación Estándar      40.87      11.07     124.39
# Asimetría (Cola)         12.54      17.71      23.91
# Curtosis                172.23     387.53     579.09
# Mínimo                    1.00       1.00       1.00
# Máximo                  640.00     255.00    3021.00
# Percentil 10              1.00       1.00       1.00
# Percentil 90              9.00       7.00       6.00

# %%
# Gráfico de innovación apilado
df_innovacion = pd.DataFrame({
    '2016-2017': df_2016['I1R1C1N'].value_counts(),
    '2018-2019': df_2018['I1R1C1N'].value_counts(),
    '2020-2021': df_2020['I1R1C1N'].value_counts()
}).rename(index={2: 'No', 1: 'Sí'})

fig, ax = plt.subplots(figsize=(8, 6))
df_innovacion.T.plot(kind='bar', stacked=True, colormap='coolwarm', ax=ax, alpha=0.8)

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='center', fontsize=12, color='White')

plt.xlabel('Periodo')
plt.ylabel('Cantidad de Empresas')
plt.title('Comparación de Innovación por Año')
plt.legend(title="¿Innovación en el Mercado?")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Pregunta 3: Comparación del número total de innovaciones por periodo

# %%
df['I1R4C2N'] = pd.to_numeric(df['I1R4C2N'], errors='coerce')
# df['I1R4C2N'] = df['I1R4C2N'].astype(int)
fig, ax = plt.subplots(figsize=(8, 6))
total_innovaciones = df.groupby('Periodo')['I1R4C2N'].sum()
total_innovaciones.plot(kind='bar', figsize=(6, 4), color=["#a50026", "#3b4cc0",'#d73027'])
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=12, color='black')
plt.title('Total de innovaciones de bienes/servicios nuevos')
plt.xlabel('Periodo')
plt.ylabel('Cantidad total de innovaciones')
plt.show()

# %%
estadisticos('I1R4C2N')
# Out:
#                      2016-2017  2018-2019  2020-2021
# Cantidad                465.00     710.00     608.00
# Media                     7.67       4.41       8.58
# Mediana                   2.00       2.00       1.00
# Moda                      1.00       1.00       1.00
# Varianza               1660.15     395.19   15221.14
# Desviación Estándar      40.74      19.88     123.37
# Asimetría (Cola)         12.35      17.84      24.10
# Curtosis                168.64     356.01     588.49
# Mínimo                    1.00       1.00       1.00
# Máximo                  640.00     436.00    3021.00
# Percentil 10              1.00       1.00       1.00
# Percentil 90              9.00       7.00       6.00

# %% [markdown]
# # Pregunta 4: Evolución de la innovación por actividad económica

# %%
emp=pd.read_excel("/content/drive/MyDrive/Talento tech/TalentoTech2/ciiu_actividad_economica.xlsx")
df=pd.merge(df,emp, left_on='CIIU4', right_on='Indice',how="inner")
df
# Out:
#         NORDEMP  CIIU4  TIPOLO  I1R1C1N I1R1C2N  I1R2C1N I1R2C2N  I1R3C1N  \
# 0      987639.0     47  AMPLIA        2                2                2
# 1      987636.0     47  NOINNO        2                2                2
# 2      987634.0     47  NOINNO        2                2                2
# 3      987633.0     47  NOINNO        2                2                2
# 4      987622.0     47  NOINNO        2                2                2
# ...         ...    ...     ...      ...     ...      ...     ...      ...
# 26039       NaN     86  NOINNO        2     NaN        2     NaN        2
# 26040       NaN     86  NOINNO        2     NaN        2     NaN        2
# 26041       NaN     86  NOINNO        2     NaN        2     NaN        2
# 26042       NaN     86  AMPLIA        1     1.0        2     NaN        2
# 26043       NaN     86  AMPLIA        2     NaN        2     NaN        2
#
#       I1R3C2N  I1R4C2N  ...  VIII14R5C1 VIII15R1C1  VIII16R1C1 VIII17R1C1  \
# ...

# %%
emp=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/TalentoTech2/ciiu_actividad_economica.xlsx")
df=pd.merge(df,emp, left_on='CIIU4', right_on='Indice',how="inner")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-9d069817faea> in <cell line: 0>()
# ----> 1 emp=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/TalentoTech2/ciiu_actividad_economica.xlsx")
#       2 df=pd.merge(df,emp, left_on='CIIU4', right_on='Indice',how="inner")
#       3 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.countplot(y=df['Actividad económica'], hue=df['Periodo'], order=df['Actividad económica'].value_counts().index, palette='coolwarm')

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=8, color='black')
plt.title('Distribución de empresas que innovan por actividad económica y año')
plt.xlabel('Número de empresas')
plt.ylabel('Actividad Económica')
plt.legend(title='Periodo')
# plt.show()

# %% [markdown]
# # Pregunta 5: Distribución de empresas por tipología y periodo

# %% [markdown]
# ## Es necesario que en el proceso de exposición tengamos en cuenta abarcar todo el tema de la tipología definiendo cada categoría.

# %%
print(df['TIPOLO'].value_counts())

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.countplot(y=df['TIPOLO'], hue=df['Periodo'], order=df['TIPOLO'].value_counts().index, palette='coolwarm')
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=12, color='black')
plt.title('Distribución de empresas por tipología y año')
plt.xlabel('Número de empresas')
plt.ylabel('Tipología')
plt.legend(title='Periodo')
plt.show()

# %% [markdown]
# # Pregunta 6: Evolución del porcentaje de empresas con bienes mejorados

# %%
fig, ax = plt.subplots(figsize=(8, 6))
bienes_mejorados = df.groupby('Periodo')['I1R1C1M'].value_counts(normalize=True).unstack() * 100
bienes_mejorados.plot(kind='bar', stacked=True, colormap='coolwarm',ax=ax)
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', label_type='center', fontsize=10, color='white')
plt.title('Porcentaje de empresas con bienes/servicios mejorados por año')
plt.xlabel('Periodo')
plt.ylabel('Porcentaje')
plt.legend(['No', 'Sí'])
plt.show()

# %%
estadisticos('I1R1C1M')
# Out:
#                      2016-2017  2018-2019  2020-2021
# Cantidad               8651.00    9304.00    8812.00
# Media                     1.96       1.94       1.95
# Mediana                   2.00       2.00       2.00
# Moda                      2.00       2.00       2.00
# Varianza                  0.04       0.05       0.05
# Desviación Estándar       0.19       0.23       0.21
# Asimetría (Cola)         -4.83      -3.83      -4.23
# Curtosis                 21.35      12.69      15.89
# Mínimo                    1.00       1.00       1.00
# Máximo                    2.00       2.00       2.00
# Percentil 10              2.00       2.00       2.00
# Percentil 90              2.00       2.00       2.00

# %% [markdown]
# # Impacto en la innvaciòn

# %%
# Cargar los datos con low_memory=False para evitar advertencias
file_paths = {
    "2016-2017": '/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv',
    "2018-2019": '/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv',
    "2020-2021": '/content/drive/MyDrive/Colab Notebooks/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv'
}

dataframes = {}
for period, path in file_paths.items():
    dataframes[period] = pd.read_csv(path, sep=';', low_memory=False)

# Diccionario de categorías
category_labels = {1: "Alta", 2: "Media", 3: "Nula", 4: "Negativo"}
impact_columns = ["I2R5C1", "I2R6C1", "I2R7C1", "I2R8C1", "I2R9C1", "I2R10C1", "I2R11C1", "I2R12C1"]
impact_labels = {
    "I2R5C1": "Aumento de la productividad",
    "I2R6C1": "Reducción de los costos laborales",
    "I2R7C1": "Reducción en el uso de materias primas o insumos",
    "I2R8C1": "Reducción en el consumo de energía u otros energéticos",
    "I2R9C1": "Reducción en el consumo de agua",
    "I2R10C1": "Reducción en costos asociados a comunicaciones",
    "I2R11C1": "Reducción en costos asociados a transporte",
    "I2R12C1": "Reducción en costos de mantenimiento y reparaciones"
}

# Convertir las columnas de impacto a numéricas
for period, df in dataframes.items():
    for col in impact_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Función para obtener proporciones de cada categoría
def get_category_proportions(df, columns):
    proportions = {category: [] for category in category_labels.values()}

    for col in columns:
        counts = df[col].value_counts(normalize=True).reindex([1, 2, 3, 4], fill_value=0)
        for cat_num, cat_label in category_labels.items():
            proportions[cat_label].append(counts[cat_num])

    return proportions

# Obtener proporciones para cada año
proportions = {period: get_category_proportions(df, impact_columns) for period, df in dataframes.items()}

# Diccionario de colores por categoría y período
colors = {
    ("Alta", "2016-2017"): "#2E7D32", ("Alta", "2018-2019"): "#66BB6A", ("Alta", "2020-2021"): "#A5D6A7",
    ("Media", "2016-2017"): "#FF8F00", ("Media", "2018-2019"): "#FFB300", ("Media", "2020-2021"): "#FFD54F",
    ("Nula", "2016-2017"): "#D84315", ("Nula", "2018-2019"): "#FF7043", ("Nula", "2020-2021"): "#FFAB91",
    ("Negativo", "2016-2017"): "#6A1B9A", ("Negativo", "2018-2019"): "#AB47BC", ("Negativo", "2020-2021"): "#CE93D8"
}

# Crear gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(14, 6))
bar_width = 0.25  # Ancho de barras
x = np.arange(len(impact_columns))  # Posiciones en X

# Dibujar barras apiladas para cada período
for i, (period, prop) in enumerate(proportions.items()):
    bottom = np.zeros(len(impact_columns)) # Inicializa la base de apilamiento
    for category in category_labels.values():
        values = prop[category] # Obtiene proporciones de la categoría
        ax.bar(x + i * bar_width, values, bar_width, label=f"{category} ({period})",
               bottom=bottom, color=colors[(category, period)])
        bottom += values # Suma para apilar
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=12, color='black')
# Configuración del gráfico
ax.set_xticks(x + bar_width)
ax.set_xticklabels([impact_labels[col] for col in impact_columns], rotation=45, ha="right")
ax.set_ylabel("Proporción de respuestas")
ax.set_title("Distribución de impacto de innovación por ítem y período")
ax.legend(title="Categoría de impacto", bbox_to_anchor=(1.05, 1), loc="upper left", ncol=2)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# Mostrar gráfico
plt.show()

# %%
# Cargar los datos con low_memory=False para evitar advertencias
file_paths = {
    "2016-2017": "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo3/EDIT_S_VI_2016_2017.csv",
    "2018-2019": "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo4/EDITS_VII_2018_2019.csv",
    "2020-2021": "/content/drive/MyDrive/Talento tech/TalentoTech2/archivo5/Estructura_EDITS_VIII_2020_2021.csv"
}

dataframes = {}
for period, path in file_paths.items():
    dataframes[period] = pd.read_csv(path, sep=';', low_memory=False)

# Diccionario de categorías
category_labels = {1: "Alta", 2: "Media", 3: "Nula", 4: "Negativo"}
impact_columns = ["I2R5C1", "I2R6C1", "I2R7C1", "I2R8C1", "I2R9C1", "I2R10C1", "I2R11C1", "I2R12C1"]
impact_labels = {
    "I2R5C1": "Aumento de la productividad",
    "I2R6C1": "Reducción de los costos laborales",
    "I2R7C1": "Reducción en el uso de materias primas o insumos",
    "I2R8C1": "Reducción en el consumo de energía u otros energéticos",
    "I2R9C1": "Reducción en el consumo de agua",
    "I2R10C1": "Reducción en costos asociados a comunicaciones",
    "I2R11C1": "Reducción en costos asociados a transporte",
    "I2R12C1": "Reducción en costos de mantenimiento y reparaciones"
}

# Convertir las columnas de impacto a numéricas
for period, df in dataframes.items():
    for col in impact_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Función para obtener proporciones de cada categoría
def get_category_proportions(df, columns):
    proportions = {category: [] for category in category_labels.values()}

    for col in columns:
        counts = df[col].value_counts(normalize=True).reindex([1, 2, 3, 4], fill_value=0)
        for cat_num, cat_label in category_labels.items():
            proportions[cat_label].append(counts[cat_num])

    return proportions

# Obtener proporciones para cada año
proportions = {period: get_category_proportions(df, impact_columns) for period, df in dataframes.items()}

# Diccionario de colores por categoría y período
colors = {
    ("Alta", "2016-2017"): "#2E7D32", ("Alta", "2018-2019"): "#66BB6A", ("Alta", "2020-2021"): "#A5D6A7",
    ("Media", "2016-2017"): "#FF8F00", ("Media", "2018-2019"): "#FFB300", ("Media", "2020-2021"): "#FFD54F",
    ("Nula", "2016-2017"): "#D84315", ("Nula", "2018-2019"): "#FF7043", ("Nula", "2020-2021"): "#FFAB91",
    ("Negativo", "2016-2017"): "#6A1B9A", ("Negativo", "2018-2019"): "#AB47BC", ("Negativo", "2020-2021"): "#CE93D8"
}

# Crear gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(14, 6))
bar_width = 0.25  # Ancho de barras
x = np.arange(len(impact_columns))  # Posiciones en X

# Dibujar barras apiladas para cada período
for i, (period, prop) in enumerate(proportions.items()):
    bottom = np.zeros(len(impact_columns)) # Inicializa la base de apilamiento
    for category in category_labels.values():
        values = prop[category] # Obtiene proporciones de la categoría
        ax.bar(x + i * bar_width, values, bar_width, label=f"{category} ({period})",
               bottom=bottom, color=colors[(category, period)])
        bottom += values # Suma para apilar
for container in ax.containers:
    ax.bar_label(container, labels=[f"{v * 100:.1f}%" for v in container.datavalues],
                 label_type='edge', fontsize=8, color='white')
# Configuración del gráfico
ax.set_xticks(x + bar_width)
ax.set_xticklabels([impact_labels[col] for col in impact_columns], rotation=45, ha="right")
ax.set_ylabel("Proporción de respuestas")
ax.set_title("Distribución de impacto de innovación por ítem y período")
ax.legend(title="Categoría de impacto", bbox_to_anchor=(1.05, 1), loc="upper left", ncol=2)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# Mostrar gráfico
plt.show()

# %%
 def estadisticos(columna):
  # Asegurar que los datos sean numéricos
  df[columna] = pd.to_numeric(df[columna], errors='coerce')

  # Filtrar datos por período
  s2016 = df[df['Periodo'] == "2016-2017"][columna]
  s2018 = df[df['Periodo'] == "2018-2019"][columna]
  s2020 = df[df['Periodo'] == "2020-2021"][columna]

  # Definir función para calcular estadísticas
  def calcular_estadisticas(data):
      return pd.Series({
          "Cantidad": data.count(),
          "Media": data.mean(),
          "Mediana": data.median(),
          "Moda": data.mode().iloc[0] if not data.mode().empty else np.nan,
          "Varianza": data.var(),
          "Desviación Estándar": data.std(),
          "Asimetría (Cola)": data.skew(),
          "Curtosis": data.kurt(),
          "Mínimo": data.min(),
          "Máximo": data.max(),
          "Percentil 10": data.quantile(0.10),
          "Percentil 90": data.quantile(0.90)
      }).round(2)

  # Calcular estadísticas por período
  stats_2016 = calcular_estadisticas(s2016)
  stats_2018 = calcular_estadisticas(s2018)
  stats_2020 = calcular_estadisticas(s2020)

  # Combinar estadísticas en un solo DataFrame
  final_stats = pd.DataFrame({
      "2016-2017": stats_2016,
      "2018-2019": stats_2018,
      "2020-2021": stats_2020
  })

  # Mostrar la tabla final
  return final_stats

# %%
columnas_codificadas = ["I2R5C1", "I2R6C1", "I2R7C1", "I2R8C1", "I2R9C1", "I2R10C1", "I2R11C1", "I2R12C1"]
# Aplicar la función a todas las columnas y combinar los DataFrames

resultados = [estadisticos(col) for col in columnas_codificadas]
df_final = pd.concat(resultados, keys=columnas_codificadas, names=["Columna", "Estadístico"])

# Mostrar la tabla final
df_final
# Out:
#                       2016-2017  2018-2019  2020-2021
# Columna Estadístico
# I2R5C1  Cantidad        1653.00    2696.00    2181.00
#         Media              1.75       1.92       1.93
#         Mediana            2.00       2.00       2.00
#         Moda               2.00       2.00       2.00
#         Varianza           0.46       0.54       0.54
# ...                         ...        ...        ...
# I2R12C1 Curtosis          -0.52      -0.17      -0.03
#         Mínimo             1.00       1.00       1.00
#         Máximo             3.00       4.00       4.00
#         Percentil 10       2.00       2.00       2.00
#         Percentil 90       3.00       3.00       3.00
#
# [96 rows x 3 columns]
